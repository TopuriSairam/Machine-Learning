# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv(r"E:\Data sets\stats.csv")

# %%
data.drop(data.tail(1).index, inplace=True)
data.head()
# Out:
#   period_start period_end  followers_gained  followers_lost  followers_net  \
# 0     5/1/2020  5/31/2020                 1               0              1
# 1     6/1/2020  6/30/2020                 8               0              8
# 2     7/1/2020  7/31/2020               103               0            103
# 3     8/1/2020  8/31/2020                46               0             46
# 4     9/1/2020  9/30/2020                35               1             34
#
#    followers_total  subscribers_gained  subscribers_lost  subscribers_net  \
# 0                1                   0                 0                0
# 1                9                   0                 0                0
# 2              112                   0                 0                0
# 3              158                   0                 0                0
# 4              192                   0                 0                0
#
#    subscribers_total    views
# 0                  0    128.0
# 1                  0  16130.0
# 2                  0  14616.0
# 3                  0   4053.0
# 4                  0   5153.0

# %%
data.tail()
# Out:
#    period_start period_end  followers_gained  followers_lost  followers_net  \
# 10     3/1/2021  3/31/2021               390               2            388
# 11     4/1/2021  4/30/2021               454               2            452
# 12     5/1/2021  5/31/2021               462               7            455
# 13     6/1/2021  6/30/2021               595               3            592
# 14     7/1/2021  7/31/2021               541               5            536
#
#     followers_total  subscribers_gained  subscribers_lost  subscribers_net  \
# 10             2355                   7                 2                5
# 11             2807                   8                 0                8
# 12             3262                   6                 0                6
# 13             3854                   5                 0                5
# 14             4390                  20                 6               14
#
#     subscribers_total     views
# 10                 37  102987.0
# 11                 45  134765.0
# 12                 51  167608.0
# 13                 56  154235.0
# 14                 70  144167.0

# %%
plt.figure(figsize=(15,10))
sns.set_theme(style='whitegrid')
plt.title("Number of Followers I Gained Every Month")
sns.barplot(x="followers_gained", y="period_end", data=data)
plt.show()

# %%
# Now let’s have a look at the total number of followers I end up with every month:
plt.figure(figsize=(15, 10))
sns.set_theme(style="whitegrid")
plt.title("Total Followers At The End of Every Month")
sns.barplot(x="followers_total", y="period_end", data=data)
plt.show()

# %%
# Now let’s take a look at one of the most important features, which is the total number of views I get each month:
plt.figure(figsize=(15, 10))
sns.set_theme(style="whitegrid")
plt.title("Total Views Every Month")
sns.barplot(x="views", y="period_end", data=data)
plt.show()

# %%
# Now I will be using the autots library in Python, which is one of the best data science libraries for time series forecasting. If you have never used this library before, you can easily install it on your system using the pip command:

# %%
# Now here’s how we can predict the increase in the number of followers we can expect to see over the next four months:

# %%
from autots import AutoTS
model = AutoTS(forecast_length=4, frequency='infer', ensemble='simple')
model = model.fit(data, date_col='period_end', value_col='followers_gained', id_col=None)
prediction = model.predict()
forecast = prediction.forecast
print(forecast)
# Out:
# Inferred frequency is: M
# Model Number: 1 with model AverageValueNaive in generation 0 of 10
# Model Number: 2 with model AverageValueNaive in generation 0 of 10
# Model Number: 3 with model AverageValueNaive in generation 0 of 10
# Model Number: 4 with model DatepartRegression in generation 0 of 10
# Model Number: 5 with model DatepartRegression in generation 0 of 10
# Model Number: 6 with model DatepartRegression in generation 0 of 10
# Model Number: 7 with model DatepartRegression in generation 0 of 10
# C:\Users\saira\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# Epoch 1/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.3863
# Epoch 2/50
# 1/1 [==============================] - 0s 20ms/step - loss: 0.3748
# Epoch 3/50
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3722
# Epoch 4/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3578
# Epoch 5/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3639
# Epoch 6/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3724
# Epoch 7/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3627
# Epoch 8/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3471
# Epoch 9/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3609
# Epoch 10/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3665
# Epoch 11/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3643
# Epoch 12/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3747
# Epoch 13/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3625
# Epoch 14/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3480
# Epoch 15/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3590
# Epoch 16/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3799
# Epoch 17/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3596
# Epoch 18/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3477
# Epoch 19/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3486
# Epoch 20/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3528
# Epoch 21/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3555
# Epoch 22/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3506
# Epoch 23/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3548
# Epoch 24/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3568
# Epoch 25/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3434
# Epoch 26/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3607
# Epoch 27/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3392
# Epoch 28/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3359
# Epoch 29/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3478
# Epoch 30/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3414
# Epoch 31/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3496
# Epoch 32/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3391
# Epoch 33/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3269
# Epoch 34/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3482
# Epoch 35/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3367
# Epoch 36/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3314
# Epoch 37/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3396
# Epoch 38/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3314
# Epoch 39/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3435
# Epoch 40/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3389
# Epoch 41/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3235
# Epoch 42/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3399
# Epoch 43/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3287
# Epoch 44/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3181
# Epoch 45/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3061
# Epoch 46/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3165
# Epoch 47/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3310
# Epoch 48/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3064
# Epoch 49/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3068
# Epoch 50/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3035
# Model Number: 8 with model ETS in generation 0 of 10
# Model Number: 9 with model ETS in generation 0 of 10
# Model Number: 10 with model GLM in generation 0 of 10
# Model Number: 11 with model GLM in generation 0 of 10
# Model Number: 12 with model GLS in generation 0 of 10
# Model Number: 13 with model GLS in generation 0 of 10
# Model Number: 14 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 14: GluonTS
# Model Number: 15 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 15: GluonTS
# Model Number: 16 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 16: GluonTS
# Model Number: 17 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 17: GluonTS
# Model Number: 18 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 18: GluonTS
# Model Number: 19 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 19: GluonTS
# Model Number: 20 with model LastValueNaive in generation 0 of 10
# Model Number: 21 with model LastValueNaive in generation 0 of 10
# Model Number: 22 with model LastValueNaive in generation 0 of 10
# Model Number: 23 with model LastValueNaive in generation 0 of 10
# Model Number: 24 with model SeasonalNaive in generation 0 of 10
# Model Number: 25 with model SeasonalNaive in generation 0 of 10
# Model Number: 26 with model SeasonalNaive in generation 0 of 10
# Model Number: 27 with model SeasonalNaive in generation 0 of 10
# Model Number: 28 with model UnobservedComponents in generation 0 of 10
# Model Number: 29 with model UnobservedComponents in generation 0 of 10
# Model Number: 30 with model UnobservedComponents in generation 0 of 10
# Model Number: 31 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 31: VAR
# Model Number: 32 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 32: VAR
# Model Number: 33 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 33: VAR
# Model Number: 34 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 34: VECM
# Model Number: 35 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 35: VECM
# Model Number: 36 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 36: VECM
# Model Number: 37 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 37: VECM
# Model Number: 38 with model WindowRegression in generation 0 of 10
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 38: WindowRegression
# Model Number: 39 with model ZeroesNaive in generation 0 of 10
# Model Number: 40 with model ZeroesNaive in generation 0 of 10
# Model Number: 41 with model LastValueNaive in generation 0 of 10
# Model Number: 42 with model AverageValueNaive in generation 0 of 10
# Model Number: 43 with model GLS in generation 0 of 10
# Model Number: 44 with model SeasonalNaive in generation 0 of 10
# Model Number: 45 with model GLM in generation 0 of 10
# Template Eval Error: ValueError('The first guess on the deviance function returned a nan.  This could be a boundary  problem and should be reported.') in model 45: GLM
# Model Number: 46 with model ETS in generation 0 of 10
# Model Number: 47 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 47: FBProphet
# Model Number: 48 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 48: GluonTS
# Model Number: 49 with model UnobservedComponents in generation 0 of 10
# Model Number: 50 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 50: VAR
# Model Number: 51 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 51: VECM
# Model Number: 52 with model WindowRegression in generation 0 of 10
# C:\Users\saira\anaconda3\lib\site-packages\statsmodels\genmod\families\family.py:1231: RuntimeWarning: invalid value encountered in log
#   resid_dev -= endog_alpha * np.log(endog_alpha / mu_alpha)
# Epoch 1/50
# 1/1 [==============================] - 3s 3s/step - loss: 125.7189
# Epoch 2/50
# 1/1 [==============================] - 0s 24ms/step - loss: 125.1879
# Epoch 3/50
# 1/1 [==============================] - 0s 10ms/step - loss: 124.6580
# Epoch 4/50
# 1/1 [==============================] - 0s 9ms/step - loss: 124.2159
# Epoch 5/50
# 1/1 [==============================] - 0s 9ms/step - loss: 124.0068
# Epoch 6/50
# 1/1 [==============================] - 0s 10ms/step - loss: 123.4354
# Epoch 7/50
# 1/1 [==============================] - 0s 9ms/step - loss: 123.0345
# Epoch 8/50
# 1/1 [==============================] - 0s 10ms/step - loss: 122.9755
# Epoch 9/50
# 1/1 [==============================] - 0s 9ms/step - loss: 121.9034
# Epoch 10/50
# 1/1 [==============================] - 0s 10ms/step - loss: 121.8202
# Epoch 11/50
# 1/1 [==============================] - 0s 10ms/step - loss: 121.1325
# Epoch 12/50
# 1/1 [==============================] - 0s 10ms/step - loss: 120.6255
# Epoch 13/50
# 1/1 [==============================] - 0s 11ms/step - loss: 120.4711
# Epoch 14/50
# 1/1 [==============================] - 0s 10ms/step - loss: 119.6906
# Epoch 15/50
# 1/1 [==============================] - 0s 11ms/step - loss: 119.3291
# Epoch 16/50
# 1/1 [==============================] - 0s 11ms/step - loss: 118.5759
# Epoch 17/50
# 1/1 [==============================] - 0s 9ms/step - loss: 117.9400
# Epoch 18/50
# 1/1 [==============================] - 0s 11ms/step - loss: 117.4655
# Epoch 19/50
# 1/1 [==============================] - 0s 9ms/step - loss: 117.2621
# Epoch 20/50
# 1/1 [==============================] - 0s 11ms/step - loss: 116.8348
# Epoch 21/50
# 1/1 [==============================] - 0s 10ms/step - loss: 116.5073
# Epoch 22/50
# 1/1 [==============================] - 0s 9ms/step - loss: 115.9692
# Epoch 23/50
# 1/1 [==============================] - 0s 11ms/step - loss: 115.8379
# Epoch 24/50
# 1/1 [==============================] - 0s 11ms/step - loss: 115.4881
# Epoch 25/50
# 1/1 [==============================] - 0s 10ms/step - loss: 115.2143
# Epoch 26/50
# 1/1 [==============================] - 0s 11ms/step - loss: 115.0193
# Epoch 27/50
# 1/1 [==============================] - 0s 10ms/step - loss: 114.6724
# Epoch 28/50
# 1/1 [==============================] - 0s 11ms/step - loss: 114.4282
# Epoch 29/50
# 1/1 [==============================] - 0s 11ms/step - loss: 114.1363
# Epoch 30/50
# 1/1 [==============================] - 0s 11ms/step - loss: 114.0422
# Epoch 31/50
# 1/1 [==============================] - 0s 10ms/step - loss: 113.9766
# Epoch 32/50
# 1/1 [==============================] - 0s 11ms/step - loss: 113.7679
# Epoch 33/50
# 1/1 [==============================] - 0s 10ms/step - loss: 113.5634
# Epoch 34/50
# 1/1 [==============================] - 0s 10ms/step - loss: 113.3887
# Epoch 35/50
# 1/1 [==============================] - 0s 11ms/step - loss: 113.2552
# Epoch 36/50
# 1/1 [==============================] - 0s 9ms/step - loss: 113.0935
# Epoch 37/50
# 1/1 [==============================] - 0s 10ms/step - loss: 113.0475
# Epoch 38/50
# 1/1 [==============================] - 0s 11ms/step - loss: 112.9019
# Epoch 39/50
# 1/1 [==============================] - 0s 11ms/step - loss: 112.7538
# Epoch 40/50
# 1/1 [==============================] - 0s 11ms/step - loss: 112.7317
# Epoch 41/50
# 1/1 [==============================] - 0s 10ms/step - loss: 112.5456
# Epoch 42/50
# 1/1 [==============================] - 0s 9ms/step - loss: 112.5082
# Epoch 43/50
# 1/1 [==============================] - 0s 11ms/step - loss: 112.4265
# Epoch 44/50
# 1/1 [==============================] - 0s 10ms/step - loss: 112.2597
# Epoch 45/50
# 1/1 [==============================] - 0s 10ms/step - loss: 112.1621
# Epoch 46/50
# 1/1 [==============================] - 0s 11ms/step - loss: 112.0898
# Epoch 47/50
# 1/1 [==============================] - 0s 10ms/step - loss: 111.9435
# Epoch 48/50
# 1/1 [==============================] - 0s 10ms/step - loss: 111.8611
# Epoch 49/50
# 1/1 [==============================] - 0s 10ms/step - loss: 111.7567
# Epoch 50/50
# 1/1 [==============================] - 0s 10ms/step - loss: 111.6609
# Model Number: 53 with model DatepartRegression in generation 0 of 10
# Model Number: 54 with model UnivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 54: UnivariateMotif
# Model Number: 55 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 55: MultivariateMotif
# Model Number: 56 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('kth(=15) out of bounds (3)') in model 56: SectionalMotif
# Model Number: 57 with model NVAR in generation 0 of 10
# Model Number: 58 with model Theta in generation 0 of 10
# Model Number: 59 with model ARDL in generation 0 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (C:\\Users\\saira\\anaconda3\\lib\\site-packages\\statsmodels\\tsa\\api.py)") in model 59: ARDL
# Model Number: 60 with model LastValueNaive in generation 0 of 10
# Model Number: 61 with model GLM in generation 0 of 10
# Template Eval Error: PerfectSeparationError('Perfect separation detected, results not available') in model 61: GLM
# Model Number: 62 with model SeasonalNaive in generation 0 of 10
# Model Number: 63 with model Theta in generation 0 of 10
# Model Number: 64 with model GLS in generation 0 of 10
# Model Number: 65 with model GLS in generation 0 of 10
# Model Number: 66 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError("regression_type=='User' but no future_regressor supplied") in model 66: SectionalMotif
# Model Number: 67 with model ZeroesNaive in generation 0 of 10
# Model Number: 68 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 68: FBProphet
# Model Number: 69 with model GLS in generation 0 of 10
# Model Number: 70 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 70: MultivariateMotif
# Model Number: 71 with model GLM in generation 0 of 10
# Model Number: 72 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 72: VAR
# Model Number: 73 with model VECM in generation 0 of 10
# Template Eval Error: LinAlgError('SVD did not converge') in model 73: VECM
# Model Number: 74 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('XA and XB must have the same number of columns (i.e. feature dimension.)') in model 74: SectionalMotif
# Model Number: 75 with model SeasonalNaive in generation 0 of 10
# Model Number: 76 with model GLS in generation 0 of 10
# Model Number: 77 with model GluonTS in generation 0 of 10
# Template Eval Error: ValueError('x must have 2 complete cycles requires 24 observations. x only has 11 observation(s)') in model 77: GluonTS
# Model Number: 78 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 78: FBProphet
# Model Number: 79 with model DatepartRegression in generation 0 of 10
# Model Number: 80 with model LastValueNaive in generation 0 of 10
# Model Number: 81 with model SeasonalNaive in generation 0 of 10
# Model Number: 82 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 82: FBProphet
# Model Number: 83 with model LastValueNaive in generation 0 of 10
# Model Number: 84 with model UnobservedComponents in generation 0 of 10
# Model Number: 85 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 85: GluonTS
# Model Number: 86 with model AverageValueNaive in generation 0 of 10
# Model Number: 87 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('Model SectionalMotif returned NaN for one or more series') in model 87: SectionalMotif
# Model Number: 88 with model UnivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 88: UnivariateMotif
# Model Number: 89 with model NVAR in generation 0 of 10
# Model Number: 90 with model WindowRegression in generation 0 of 10
# C:\Users\saira\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\saira\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1366: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 2 is required.') in model 90: WindowRegression
# Model Number: 91 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 91: VAR
# Model Number: 92 with model NVAR in generation 0 of 10
# Model Number: 93 with model ETS in generation 0 of 10
# Template Eval Error: ValueError('x must have 2 complete cycles requires 24 observations. x only has 11 observation(s)') in model 93: ETS
# Model Number: 94 with model UnivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 94: UnivariateMotif
# Model Number: 95 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('XA and XB must have the same number of columns (i.e. feature dimension.)') in model 95: SectionalMotif
# Model Number: 96 with model DatepartRegression in generation 0 of 10
# Model Number: 97 with model WindowRegression in generation 0 of 10
# Model Number: 98 with model AverageValueNaive in generation 0 of 10
# Model Number: 99 with model ARDL in generation 0 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (C:\\Users\\saira\\anaconda3\\lib\\site-packages\\statsmodels\\tsa\\api.py)") in model 99: ARDL
# Model Number: 100 with model GLS in generation 0 of 10
# Model Number: 101 with model WindowRegression in generation 0 of 10
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 101: WindowRegression
# Model Number: 102 with model AverageValueNaive in generation 0 of 10
# Template Eval Error: ValueError('zero-size array to reduction operation maximum which has no identity') in model 102: AverageValueNaive
# Model Number: 103 with model LastValueNaive in generation 0 of 10
# C:\Users\saira\anaconda3\lib\site-packages\sklearn\neighbors\_regression.py:421: UserWarning: One or more samples have no neighbors within specified radius; predicting NaN.
#   warnings.warn(empty_warning_msg)
# Model Number: 104 with model GLS in generation 0 of 10
# Model Number: 105 with model UnivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 105: UnivariateMotif
# Model Number: 106 with model LastValueNaive in generation 0 of 10
# Model Number: 107 with model GLS in generation 0 of 10
# Model Number: 108 with model ZeroesNaive in generation 0 of 10
# Model Number: 109 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 109: VECM
# Model Number: 110 with model ZeroesNaive in generation 0 of 10
# Model Number: 111 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 111: GluonTS
# Model Number: 112 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 112: ARDL
# Model Number: 113 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 113: GluonTS
# Model Number: 114 with model GLM in generation 0 of 10
# Model Number: 115 with model NVAR in generation 0 of 10
# Model Number: 116 with model LastValueNaive in generation 0 of 10
# Model Number: 117 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 117: ARDL
# Model Number: 118 with model ARDL in generation 0 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (C:\\Users\\saira\\anaconda3\\lib\\site-packages\\statsmodels\\tsa\\api.py)") in model 118: ARDL
# Model Number: 119 with model SeasonalNaive in generation 0 of 10
# Model Number: 120 with model NVAR in generation 0 of 10
# Model Number: 121 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 121: GluonTS
# Model Number: 122 with model UnivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 122: UnivariateMotif
# Model Number: 123 with model LastValueNaive in generation 0 of 10
# Model Number: 124 with model LastValueNaive in generation 0 of 10
# Model Number: 125 with model AverageValueNaive in generation 0 of 10
# Model Number: 126 with model ZeroesNaive in generation 0 of 10
# Model Number: 127 with model SeasonalNaive in generation 0 of 10
# Model Number: 128 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 128: MultivariateMotif
# Model Number: 129 with model AverageValueNaive in generation 0 of 10
# Model Number: 130 with model DatepartRegression in generation 0 of 10
# Model Number: 131 with model Theta in generation 0 of 10
# Model Number: 132 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 132: VAR
# Model Number: 133 with model FBProphet in generation 0 of 10
# Template Eval Error: ValueError('x must have 2 complete cycles requires 24 observations. x only has 11 observation(s)') in model 133: FBProphet
# Model Number: 134 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 134: MultivariateMotif
# Model Number: 135 with model UnobservedComponents in generation 0 of 10
# C:\Users\saira\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# Model Number: 136 with model NVAR in generation 0 of 10
# Model Number: 137 with model WindowRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 137: WindowRegression
# Model Number: 138 with model Theta in generation 0 of 10
# Model Number: 139 with model LastValueNaive in generation 0 of 10
# New Generation: 1 of 10
# Model Number: 140 with model LastValueNaive in generation 1 of 10
# Model Number: 141 with model LastValueNaive in generation 1 of 10
# Model Number: 142 with model DatepartRegression in generation 1 of 10
# Model Number: 143 with model DatepartRegression in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 143: DatepartRegression
# Model Number: 144 with model DatepartRegression in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 144: DatepartRegression
# Model Number: 145 with model NVAR in generation 1 of 10
# Model Number: 146 with model NVAR in generation 1 of 10
# Model Number: 147 with model NVAR in generation 1 of 10
# Model Number: 148 with model NVAR in generation 1 of 10
# Model Number: 149 with model SeasonalNaive in generation 1 of 10
# C:\Users\saira\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# Model Number: 150 with model SeasonalNaive in generation 1 of 10
# Model Number: 151 with model SeasonalNaive in generation 1 of 10
# Model Number: 152 with model SeasonalNaive in generation 1 of 10
# Model Number: 153 with model AverageValueNaive in generation 1 of 10
# Model Number: 154 with model AverageValueNaive in generation 1 of 10
# Model Number: 155 with model AverageValueNaive in generation 1 of 10
# Model Number: 156 with model Theta in generation 1 of 10
# Model Number: 157 with model Theta in generation 1 of 10
# C:\Users\saira\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# Model Number: 158 with model Theta in generation 1 of 10
# Model Number: 159 with model Theta in generation 1 of 10
# Model Number: 160 with model GLS in generation 1 of 10
# Model Number: 161 with model GLS in generation 1 of 10
# Model Number: 162 with model GLS in generation 1 of 10
# Model Number: 163 with model UnobservedComponents in generation 1 of 10
# Model Number: 164 with model UnobservedComponents in generation 1 of 10
# Model Number: 165 with model UnobservedComponents in generation 1 of 10
# Model Number: 166 with model ZeroesNaive in generation 1 of 10
# Model Number: 167 with model ZeroesNaive in generation 1 of 10
# Template Eval Error: ValueError('NaN in DifferencedTransformer.inverse_transform') in model 167: ZeroesNaive
# Model Number: 168 with model ZeroesNaive in generation 1 of 10
# Model Number: 169 with model ETS in generation 1 of 10
# Model Number: 170 with model ETS in generation 1 of 10
# Model Number: 171 with model ETS in generation 1 of 10
# Model Number: 172 with model ETS in generation 1 of 10
# Model Number: 173 with model WindowRegression in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 173: WindowRegression
# Model Number: 174 with model WindowRegression in generation 1 of 10
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Model Number: 175 with model WindowRegression in generation 1 of 10
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 2 is required.') in model 175: WindowRegression
# Model Number: 176 with model GLM in generation 1 of 10
# Model Number: 177 with model GLM in generation 1 of 10
# Model Number: 178 with model GLM in generation 1 of 10
# Model Number: 179 with model GLM in generation 1 of 10
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    0.0s finished
# Model Number: 180 with model GluonTS in generation 1 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 180: GluonTS
# Model Number: 181 with model GluonTS in generation 1 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 181: GluonTS
# Model Number: 182 with model GluonTS in generation 1 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 182: GluonTS
# Model Number: 183 with model GluonTS in generation 1 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 183: GluonTS
# Model Number: 184 with model VAR in generation 1 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 184: VAR
# Model Number: 185 with model VAR in generation 1 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 185: VAR
# Model Number: 186 with model VAR in generation 1 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 186: VAR
# Model Number: 187 with model VAR in generation 1 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 187: VAR
# Model Number: 188 with model VECM in generation 1 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 188: VECM
# Model Number: 189 with model VECM in generation 1 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 189: VECM
# Model Number: 190 with model VECM in generation 1 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 190: VECM
# Model Number: 191 with model VECM in generation 1 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 191: VECM
# Model Number: 192 with model FBProphet in generation 1 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 192: FBProphet
# Model Number: 193 with model FBProphet in generation 1 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 193: FBProphet
# Model Number: 194 with model FBProphet in generation 1 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 194: FBProphet
# Model Number: 195 with model FBProphet in generation 1 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 195: FBProphet
# Model Number: 196 with model UnivariateMotif in generation 1 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 196: UnivariateMotif
# Model Number: 197 with model UnivariateMotif in generation 1 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 197: UnivariateMotif
# Model Number: 198 with model UnivariateMotif in generation 1 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 198: UnivariateMotif
# Model Number: 199 with model UnivariateMotif in generation 1 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 199: UnivariateMotif
# Model Number: 200 with model MultivariateMotif in generation 1 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 200: MultivariateMotif
# Model Number: 201 with model MultivariateMotif in generation 1 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 201: MultivariateMotif
# Model Number: 202 with model MultivariateMotif in generation 1 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 202: MultivariateMotif
# Model Number: 203 with model MultivariateMotif in generation 1 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 203: MultivariateMotif
# Model Number: 204 with model SectionalMotif in generation 1 of 10
# Template Eval Error: ValueError('XA and XB must have the same number of columns (i.e. feature dimension.)') in model 204: SectionalMotif
# Model Number: 205 with model SectionalMotif in generation 1 of 10
# Template Eval Error: ValueError('Model SectionalMotif returned NaN for one or more series') in model 205: SectionalMotif
# Model Number: 206 with model SectionalMotif in generation 1 of 10
# Template Eval Error: ValueError('XA and XB must have the same number of columns (i.e. feature dimension.)') in model 206: SectionalMotif
# Model Number: 207 with model SectionalMotif in generation 1 of 10
# Template Eval Error: ValueError('The number of observations (1) is too small; the covariance matrix is singular. For observations with 10 dimensions, at least 11 observations are required.') in model 207: SectionalMotif
# Model Number: 208 with model ARDL in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 208: ARDL
# Model Number: 209 with model ARDL in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 209: ARDL
# Model Number: 210 with model ARDL in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 210: ARDL
# Model Number: 211 with model ARDL in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 211: ARDL
# New Generation: 2 of 10
# Model Number: 212 with model LastValueNaive in generation 2 of 10
# C:\Users\saira\anaconda3\lib\site-packages\autots\models\basics.py:1860: RuntimeWarning: Mean of empty slice
#   forecast = np.nanmean(results, axis=0)
# C:\Users\saira\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1366: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Model Number: 213 with model AverageValueNaive in generation 2 of 10
# Model Number: 214 with model AverageValueNaive in generation 2 of 10
# Model Number: 215 with model AverageValueNaive in generation 2 of 10
# Model Number: 216 with model ETS in generation 2 of 10
# Model Number: 217 with model ETS in generation 2 of 10
# Model Number: 218 with model ETS in generation 2 of 10
# Model Number: 219 with model ETS in generation 2 of 10
# Model Number: 220 with model NVAR in generation 2 of 10
# Model Number: 221 with model NVAR in generation 2 of 10
# Template Eval Error: IndexError('index -3 is out of bounds for axis 1 with size 2') in model 221: NVAR
# Model Number: 222 with model NVAR in generation 2 of 10
# Model Number: 223 with model NVAR in generation 2 of 10
# Model Number: 224 with model Theta in generation 2 of 10
# Template Eval Error: ValueError('x must have 2 complete cycles requires 24 observations. x only has 5 observation(s)') in model 224: Theta
# Model Number: 225 with model Theta in generation 2 of 10
# Template Eval Error: ValueError('x must have 2 complete cycles requires 24 observations. x only has 11 observation(s)') in model 225: Theta
# Model Number: 226 with model Theta in generation 2 of 10
# Model Number: 227 with model Theta in generation 2 of 10
# Model Number: 228 with model DatepartRegression in generation 2 of 10
# Model Number: 229 with model DatepartRegression in generation 2 of 10
# C:\Users\saira\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\Users\saira\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# Model Number: 230 with model DatepartRegression in generation 2 of 10
# Model Number: 231 with model UnobservedComponents in generation 2 of 10
# Model Number: 232 with model UnobservedComponents in generation 2 of 10
# Model Number: 233 with model UnobservedComponents in generation 2 of 10
# Model Number: 234 with model SeasonalNaive in generation 2 of 10
# Model Number: 235 with model SeasonalNaive in generation 2 of 10
# Model Number: 236 with model SeasonalNaive in generation 2 of 10
# Model Number: 237 with model SeasonalNaive in generation 2 of 10
# Model Number: 238 with model GLS in generation 2 of 10
# Model Number: 239 with model GLS in generation 2 of 10
# Model Number: 240 with model GLS in generation 2 of 10
# Model Number: 241 with model ZeroesNaive in generation 2 of 10
# Model Number: 242 with model ZeroesNaive in generation 2 of 10
# Model Number: 243 with model WindowRegression in generation 2 of 10
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 243: WindowRegression
# Model Number: 244 with model WindowRegression in generation 2 of 10
# Model Number: 245 with model WindowRegression in generation 2 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 245: WindowRegression
# Model Number: 246 with model GLM in generation 2 of 10
# Model Number: 247 with model GLM in generation 2 of 10
# Model Number: 248 with model GLM in generation 2 of 10
# C:\Users\saira\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Model Number: 249 with model GLM in generation 2 of 10
# Template Eval Error: ValueError('regression_type=user and no future_regressor passed') in model 249: GLM
# Model Number: 250 with model GluonTS in generation 2 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 250: GluonTS
# Model Number: 251 with model GluonTS in generation 2 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 251: GluonTS
# Model Number: 252 with model GluonTS in generation 2 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 252: GluonTS
# Model Number: 253 with model GluonTS in generation 2 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 253: GluonTS
# Model Number: 254 with model VAR in generation 2 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 254: VAR
# Model Number: 255 with model VAR in generation 2 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 255: VAR
# Model Number: 256 with model VAR in generation 2 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 256: VAR
# Model Number: 257 with model VAR in generation 2 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 257: VAR
# Model Number: 258 with model VECM in generation 2 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 258: VECM
# Model Number: 259 with model VECM in generation 2 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 259: VECM
# Model Number: 260 with model VECM in generation 2 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 260: VECM
# Model Number: 261 with model VECM in generation 2 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 261: VECM
# Model Number: 262 with model FBProphet in generation 2 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 262: FBProphet
# Model Number: 263 with model FBProphet in generation 2 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 263: FBProphet
# Model Number: 264 with model FBProphet in generation 2 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 264: FBProphet
# Model Number: 265 with model FBProphet in generation 2 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 265: FBProphet
# Model Number: 266 with model UnivariateMotif in generation 2 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 266: UnivariateMotif
# Model Number: 267 with model UnivariateMotif in generation 2 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 267: UnivariateMotif
# Model Number: 268 with model UnivariateMotif in generation 2 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 268: UnivariateMotif
# Model Number: 269 with model UnivariateMotif in generation 2 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 269: UnivariateMotif
# Model Number: 270 with model MultivariateMotif in generation 2 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 270: MultivariateMotif
# Model Number: 271 with model MultivariateMotif in generation 2 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 271: MultivariateMotif
# Model Number: 272 with model MultivariateMotif in generation 2 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 272: MultivariateMotif
# Model Number: 273 with model MultivariateMotif in generation 2 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 273: MultivariateMotif
# Model Number: 274 with model SectionalMotif in generation 2 of 10
# Template Eval Error: ValueError('kth(=10) out of bounds (1)') in model 274: SectionalMotif
# Model Number: 275 with model SectionalMotif in generation 2 of 10
# Template Eval Error: ValueError('XA and XB must have the same number of columns (i.e. feature dimension.)') in model 275: SectionalMotif
# Model Number: 276 with model SectionalMotif in generation 2 of 10
# Template Eval Error: ValueError('kth(=15) out of bounds (3)') in model 276: SectionalMotif
# Model Number: 277 with model SectionalMotif in generation 2 of 10
# Template Eval Error: ValueError('XA and XB must have the same number of columns (i.e. feature dimension.)') in model 277: SectionalMotif
# Model Number: 278 with model ARDL in generation 2 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (C:\\Users\\saira\\anaconda3\\lib\\site-packages\\statsmodels\\tsa\\api.py)") in model 278: ARDL
# Model Number: 279 with model ARDL in generation 2 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 279: ARDL
# Model Number: 280 with model ARDL in generation 2 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (C:\\Users\\saira\\anaconda3\\lib\\site-packages\\statsmodels\\tsa\\api.py)") in model 280: ARDL
# Model Number: 281 with model ARDL in generation 2 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (C:\\Users\\saira\\anaconda3\\lib\\site-packages\\statsmodels\\tsa\\api.py)") in model 281: ARDL
# New Generation: 3 of 10
# Model Number: 282 with model NVAR in generation 3 of 10
# Model Number: 283 with model NVAR in generation 3 of 10
# Model Number: 284 with model NVAR in generation 3 of 10
# Model Number: 285 with model NVAR in generation 3 of 10
# Model Number: 286 with model LastValueNaive in generation 3 of 10
# Model Number: 287 with model LastValueNaive in generation 3 of 10
# Model Number: 288 with model LastValueNaive in generation 3 of 10
# Model Number: 289 with model AverageValueNaive in generation 3 of 10
# Template Eval Error: ValueError("Input contains NaN, infinity or a value too large for dtype('float64').") in model 289: AverageValueNaive
# Model Number: 290 with model AverageValueNaive in generation 3 of 10
# Model Number: 291 with model AverageValueNaive in generation 3 of 10
# Model Number: 292 with model ETS in generation 3 of 10
# Model Number: 293 with model ETS in generation 3 of 10
# Model Number: 294 with model ETS in generation 3 of 10
# Model Number: 295 with model ETS in generation 3 of 10
# Model Number: 296 with model Theta in generation 3 of 10
# Model Number: 297 with model Theta in generation 3 of 10
# C:\Users\saira\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
#   model = cd_fast.enet_coordinate_descent(
# Model Number: 298 with model Theta in generation 3 of 10
# Model Number: 299 with model Theta in generation 3 of 10
# Model Number: 300 with model DatepartRegression in generation 3 of 10
# Model Number: 301 with model DatepartRegression in generation 3 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 301: DatepartRegression
# Model Number: 302 with model DatepartRegression in generation 3 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 302: DatepartRegression
# Model Number: 303 with model SeasonalNaive in generation 3 of 10
# Model Number: 304 with model SeasonalNaive in generation 3 of 10
# Model Number: 305 with model SeasonalNaive in generation 3 of 10
# Model Number: 306 with model SeasonalNaive in generation 3 of 10
# Model Number: 307 with model UnobservedComponents in generation 3 of 10
# Model Number: 308 with model UnobservedComponents in generation 3 of 10
# Model Number: 309 with model UnobservedComponents in generation 3 of 10
# Model Number: 310 with model GLS in generation 3 of 10
# Model Number: 311 with model GLS in generation 3 of 10
# Model Number: 312 with model GLS in generation 3 of 10
# Model Number: 313 with model ZeroesNaive in generation 3 of 10
# Model Number: 314 with model GLM in generation 3 of 10
# Template Eval Error: ValueError('regression_type=user and no future_regressor passed') in model 314: GLM
# Model Number: 315 with model GLM in generation 3 of 10
# Template Eval Error: ValueError('regression_type=user and no future_regressor passed') in model 315: GLM
# Model Number: 316 with model GLM in generation 3 of 10
# Model Number: 317 with model GLM in generation 3 of 10
# Template Eval Error: ValueError('regression_type=user and no future_regressor passed') in model 317: GLM
# Model Number: 318 with model WindowRegression in generation 3 of 10
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 318: WindowRegression
# Model Number: 319 with model WindowRegression in generation 3 of 10
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 319: WindowRegression
# Model Number: 320 with model WindowRegression in generation 3 of 10
# Model Number: 321 with model GluonTS in generation 3 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 321: GluonTS
# ...
# 2 - Ensemble with avg smape 100.39:
# Model Number: 3 of 100 with model Ensemble for Validation 2
# 3 - Ensemble with avg smape 95.48:
# Model Number: 4 of 100 with model Ensemble for Validation 2
# Traceback (most recent call last):
#   File "C:\Users\saira\anaconda3\lib\site-packages\autots\evaluator\auto_model.py", line 848, in model_forecast
#     df_forecast = model_forecast(
#   File "C:\Users\saira\anaconda3\lib\site-packages\autots\evaluator\auto_model.py", line 932, in model_forecast
#     df_forecast = ModelPrediction(
#   File "C:\Users\saira\anaconda3\lib\site-packages\autots\evaluator\auto_model.py", line 549, in ModelPrediction
#     df_forecast = model.predict(
#   File "C:\Users\saira\anaconda3\lib\site-packages\autots\models\basics.py", line 1581, in predict
#     fore, up, low = predict_reservoir(
#   File "C:\Users\saira\anaconda3\lib\site-packages\autots\models\basics.py", line 1441, in predict_reservoir
#     x_int[:, 0] = x[:, warmtrain_pts - 2 - ns]
# IndexError: index -4 is out of bounds for axis 1 with size 3
#
# FAILED: Ensemble BestN component 1 of 3 with error: IndexError('index -4 is out of bounds for axis 1 with size 3')
# 4 - Ensemble with avg smape 97.59:
# Model Number: 5 of 100 with model SeasonalNaive for Validation 2
# 5 - SeasonalNaive with avg smape 93.11:
# Model Number: 6 of 100 with model SeasonalNaive for Validation 2
# 6 - SeasonalNaive with avg smape 93.5:
# Model Number: 7 of 100 with model SeasonalNaive for Validation 2
# 7 - SeasonalNaive with avg smape 93.11:
# Model Number: 8 of 100 with model SeasonalNaive for Validation 2
# 8 - SeasonalNaive with avg smape 93.11:
# Model Number: 9 of 100 with model SeasonalNaive for Validation 2
# 9 - SeasonalNaive with avg smape 93.5:
# Model Number: 10 of 100 with model SeasonalNaive for Validation 2
# 10 - SeasonalNaive with avg smape 93.5:
# Model Number: 11 of 100 with model NVAR for Validation 2
# Template Eval Error: IndexError('index -4 is out of bounds for axis 1 with size 3') in model 11: NVAR
# Model Number: 12 of 100 with model SeasonalNaive for Validation 2
# 12 - SeasonalNaive with avg smape 95.88:
# Model Number: 13 of 100 with model NVAR for Validation 2
# Template Eval Error: IndexError('index -4 is out of bounds for axis 1 with size 3') in model 13: NVAR
# Model Number: 14 of 100 with model NVAR for Validation 2
# Template Eval Error: IndexError('index -4 is out of bounds for axis 1 with size 3') in model 14: NVAR
# Model Number: 15 of 100 with model NVAR for Validation 2
# Template Eval Error: IndexError('index -4 is out of bounds for axis 1 with size 3') in model 15: NVAR
# Model Number: 16 of 100 with model NVAR for Validation 2
# Template Eval Error: IndexError('index -4 is out of bounds for axis 1 with size 3') in model 16: NVAR
# Model Number: 17 of 100 with model SeasonalNaive for Validation 2
# 17 - SeasonalNaive with avg smape 93.5:
# Model Number: 18 of 100 with model LastValueNaive for Validation 2
# 18 - LastValueNaive with avg smape 101.01:
# Model Number: 19 of 100 with model LastValueNaive for Validation 2
# 19 - LastValueNaive with avg smape 101.01:
# Model Number: 20 of 100 with model LastValueNaive for Validation 2
# 20 - LastValueNaive with avg smape 101.01:
# Model Number: 21 of 100 with model LastValueNaive for Validation 2
# 21 - LastValueNaive with avg smape 101.01:
# Model Number: 22 of 100 with model LastValueNaive for Validation 2
# 22 - LastValueNaive with avg smape 101.01:
# Model Number: 23 of 100 with model LastValueNaive for Validation 2
# 23 - LastValueNaive with avg smape 101.01:
# Model Number: 24 of 100 with model LastValueNaive for Validation 2
# 24 - LastValueNaive with avg smape 101.0:
# Model Number: 25 of 100 with model LastValueNaive for Validation 2
# 25 - LastValueNaive with avg smape 97.98:
# Model Number: 26 of 100 with model NVAR for Validation 2
# Template Eval Error: IndexError('index -4 is out of bounds for axis 1 with size 3') in model 26: NVAR
# Model Number: 27 of 100 with model Theta for Validation 2
# 27 - Theta with avg smape 99.49:
# Model Number: 28 of 100 with model Ensemble for Validation 2
# 28 - Ensemble with avg smape 90.43:
# Model Number: 29 of 100 with model AverageValueNaive for Validation 2
# 29 - AverageValueNaive with avg smape 93.5:
# Model Number: 30 of 100 with model UnobservedComponents for Validation 2
# 30 - UnobservedComponents with avg smape 134.44:
# Model Number: 31 of 100 with model UnobservedComponents for Validation 2
# 31 - UnobservedComponents with avg smape 118.82:
# Model Number: 32 of 100 with model UnobservedComponents for Validation 2
# 32 - UnobservedComponents with avg smape 92.8:
# Model Number: 33 of 100 with model UnobservedComponents for Validation 2
# 33 - UnobservedComponents with avg smape 98.86:
# Model Number: 34 of 100 with model AverageValueNaive for Validation 2
# 34 - AverageValueNaive with avg smape 98.86:
# Model Number: 35 of 100 with model AverageValueNaive for Validation 2
# 35 - AverageValueNaive with avg smape 98.86:
# Model Number: 36 of 100 with model NVAR for Validation 2
# Template Eval Error: IndexError('index -4 is out of bounds for axis 1 with size 3') in model 36: NVAR
# Model Number: 37 of 100 with model NVAR for Validation 2
# Template Eval Error: IndexError('index -4 is out of bounds for axis 1 with size 3') in model 37: NVAR
# Model Number: 38 of 100 with model ETS for Validation 2
# 38 - ETS with avg smape 98.86:
# Model Number: 39 of 100 with model ETS for Validation 2
# 39 - ETS with avg smape 98.86:
# Model Number: 40 of 100 with model ETS for Validation 2
# 40 - ETS with avg smape 98.86:
# Model Number: 41 of 100 with model ETS for Validation 2
# 41 - ETS with avg smape 98.86:
# Model Number: 42 of 100 with model ETS for Validation 2
# 42 - ETS with avg smape 98.86:
# Model Number: 43 of 100 with model ETS for Validation 2
# 43 - ETS with avg smape 98.86:
# Model Number: 44 of 100 with model ETS for Validation 2
# 44 - ETS with avg smape 98.8:
# Model Number: 45 of 100 with model ETS for Validation 2
# 45 - ETS with avg smape 98.86:
# Model Number: 46 of 100 with model AverageValueNaive for Validation 2
# 46 - AverageValueNaive with avg smape 99.43:
# Model Number: 47 of 100 with model AverageValueNaive for Validation 2
# 47 - AverageValueNaive with avg smape 99.43:
# Model Number: 48 of 100 with model GLM for Validation 2
# 48 - GLM with avg smape 98.86:
# Model Number: 49 of 100 with model GLM for Validation 2
# 49 - GLM with avg smape 95.96:
# Model Number: 50 of 100 with model AverageValueNaive for Validation 2
# 50 - AverageValueNaive with avg smape 99.78:
# Model Number: 51 of 100 with model AverageValueNaive for Validation 2
# 51 - AverageValueNaive with avg smape 99.63:
# C:\Users\saira\anaconda3\lib\site-packages\statsmodels\genmod\families\family.py:428: RuntimeWarning: divide by zero encountered in true_divide
#   endog_mu = self._clean(endog / mu)
# Model Number: 52 of 100 with model AverageValueNaive for Validation 2
# 52 - AverageValueNaive with avg smape 93.5:
# Model Number: 53 of 100 with model Theta for Validation 2
# 53 - Theta with avg smape 97.54:
# Model Number: 54 of 100 with model Theta for Validation 2
# 54 - Theta with avg smape 97.54:
# Model Number: 55 of 100 with model GLM for Validation 2
# 55 - GLM with avg smape 93.11:
# Model Number: 56 of 100 with model Theta for Validation 2
# 56 - Theta with avg smape 99.71:
# Model Number: 57 of 100 with model Theta for Validation 2
# 57 - Theta with avg smape 97.73:
# Model Number: 58 of 100 with model Theta for Validation 2
# 58 - Theta with avg smape 97.73:
# Model Number: 59 of 100 with model ZeroesNaive for Validation 2
# 59 - ZeroesNaive with avg smape 97.73:
# Model Number: 60 of 100 with model Theta for Validation 2
# 60 - Theta with avg smape 97.73:
# Model Number: 61 of 100 with model Theta for Validation 2
# 61 - Theta with avg smape 99.5:
# Model Number: 62 of 100 with model GLM for Validation 2
# C:\Users\saira\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# 62 - GLM with avg smape 93.5:
# Model Number: 63 of 100 with model DatepartRegression for Validation 2
# 63 - DatepartRegression with avg smape 191.55:
# Model Number: 64 of 100 with model GLM for Validation 2
# Template Eval Error: ValueError('The first guess on the deviance function returned a nan.  This could be a boundary  problem and should be reported.') in model 64: GLM
# Model Number: 65 of 100 with model GLM for Validation 2
# 65 - GLM with avg smape 95.94:
# Model Number: 66 of 100 with model DatepartRegression for Validation 2
# 66 - DatepartRegression with avg smape 191.55:
# Model Number: 67 of 100 with model UnobservedComponents for Validation 2
# C:\Users\saira\anaconda3\lib\site-packages\statsmodels\genmod\generalized_linear_model.py:293: DomainWarning: The inverse_power link function does not respect the domain of the Gamma family.
#   warnings.warn((f"The {type(family.link).__name__} link function "
# C:\Users\saira\anaconda3\lib\site-packages\statsmodels\genmod\families\family.py:179: RuntimeWarning: invalid value encountered in true_divide
#   return np.sum(resid_dev * freq_weights * var_weights / scale)
# C:\Users\saira\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
#   model = cd_fast.enet_coordinate_descent(
# 67 - UnobservedComponents with avg smape 101.77:
# Model Number: 68 of 100 with model WindowRegression for Validation 2
# Template Eval Error: ValueError('Exception encountered when calling layer "conv1d" (type Conv1D).\n\nNegative dimension size caused by subtracting 1 from 0 for \'{{node conv1d/Conv1D}} = Conv2D[T=DT_FLOAT, data_format="NHWC", dilations=[1, 1, 1, 1], explicit_paddings=[], padding="VALID", strides=[1, 1, 1, 1], use_cudnn_on_gpu=true](conv1d/Conv1D/ExpandDims, conv1d/Conv1D/ExpandDims_1)\' with input shapes: [?,1,0,1], [1,1,1,4].\n\nCall arguments received:\n  • inputs=tf.Tensor(shape=(None, 0, 1), dtype=float32)') in model 68: WindowRegression
# Model Number: 69 of 100 with model GLM for Validation 2
# 69 - GLM with avg smape 96.82:
# Model Number: 70 of 100 with model UnobservedComponents for Validation 2
# C:\Users\saira\anaconda3\lib\site-packages\statsmodels\genmod\families\family.py:1231: RuntimeWarning: invalid value encountered in log
#   resid_dev -= endog_alpha * np.log(endog_alpha / mu_alpha)
# 70 - UnobservedComponents with avg smape 95.94:
# Model Number: 71 of 100 with model GLS for Validation 2
# 71 - GLS with avg smape 139.99:
# Model Number: 72 of 100 with model GLS for Validation 2
# 72 - GLS with avg smape 99.78:
# Model Number: 73 of 100 with model GLS for Validation 2
# 73 - GLS with avg smape 75.61:
# Model Number: 74 of 100 with model UnobservedComponents for Validation 2
# 74 - UnobservedComponents with avg smape 95.94:
# Model Number: 75 of 100 with model DatepartRegression for Validation 2
# 75 - DatepartRegression with avg smape 101.77:
# Model Number: 76 of 100 with model UnobservedComponents for Validation 2
# C:\Users\saira\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# 76 - UnobservedComponents with avg smape 95.94:
# Model Number: 77 of 100 with model GLS for Validation 2
# 77 - GLS with avg smape 144.17:
# Model Number: 78 of 100 with model DatepartRegression for Validation 2
# 78 - DatepartRegression with avg smape 94.92:
# Model Number: 79 of 100 with model GLS for Validation 2
# 79 - GLS with avg smape 101.76:
# Model Number: 80 of 100 with model GLS for Validation 2
# 80 - GLS with avg smape 191.55:
# Model Number: 81 of 100 with model GLS for Validation 2
# 81 - GLS with avg smape 191.55:
# Model Number: 82 of 100 with model GLS for Validation 2
# 82 - GLS with avg smape 191.55:
# Model Number: 83 of 100 with model DatepartRegression for Validation 2
# 83 - DatepartRegression with avg smape 95.94:
# Model Number: 84 of 100 with model GLM for Validation 2
# Template Eval Error: ValueError('The first guess on the deviance function returned a nan.  This could be a boundary  problem and should be reported.') in model 84: GLM
# Model Number: 85 of 100 with model ZeroesNaive for Validation 2
# 85 - ZeroesNaive with avg smape 96.33:
# Model Number: 86 of 100 with model ZeroesNaive for Validation 2
# 86 - ZeroesNaive with avg smape 96.37:
# Model Number: 87 of 100 with model ZeroesNaive for Validation 2
# C:\Users\saira\anaconda3\lib\site-packages\statsmodels\genmod\families\family.py:179: RuntimeWarning: invalid value encountered in true_divide
#   return np.sum(resid_dev * freq_weights * var_weights / scale)
# 87 - ZeroesNaive with avg smape 93.77:
# Model Number: 88 of 100 with model ZeroesNaive for Validation 2
# 88 - ZeroesNaive with avg smape 103.53:
# Model Number: 89 of 100 with model ZeroesNaive for Validation 2
# 89 - ZeroesNaive with avg smape 96.37:
# Model Number: 90 of 100 with model DatepartRegression for Validation 2
# 90 - DatepartRegression with avg smape 100.38:
# Model Number: 91 of 100 with model ZeroesNaive for Validation 2
# 91 - ZeroesNaive with avg smape 100.38:
# Model Number: 92 of 100 with model DatepartRegression for Validation 2
# 92 - DatepartRegression with avg smape 134.44:
# Model Number: 93 of 100 with model DatepartRegression for Validation 2
# 93 - DatepartRegression with avg smape 100.38:
# Model Number: 94 of 100 with model ZeroesNaive for Validation 2
# 94 - ZeroesNaive with avg smape 154.81:
# Model Number: 95 of 100 with model WindowRegression for Validation 2
# C:\Users\saira\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# Template Eval Error: ValueError('Exception encountered when calling layer "gru" (type GRU).\n\nslice index 0 of dimension 0 out of bounds. for \'{{node strided_slice_1}} = StridedSlice[Index=DT_INT32, T=DT_FLOAT, begin_mask=0, ellipsis_mask=0, end_mask=0, new_axis_mask=0, shrink_axis_mask=1](transpose, strided_slice_1/stack, strided_slice_1/stack_1, strided_slice_1/stack_2)\' with input shapes: [0,?,1], [1], [1], [1] and with computed input tensors: input[1] = <0>, input[2] = <1>, input[3] = <1>.\n\nCall arguments received:\n  • inputs=tf.Tensor(shape=(None, 0, 1), dtype=float32)\n  • mask=None\n  • training=None\n  • initial_state=None') in model 95: WindowRegression
# Model Number: 96 of 100 with model WindowRegression for Validation 2
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 96: WindowRegression
# Model Number: 97 of 100 with model WindowRegression for Validation 2
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 97: WindowRegression
# Model Number: 98 of 100 with model WindowRegression for Validation 2
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 98: WindowRegression
# Model Number: 99 of 100 with model WindowRegression for Validation 2
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 99: WindowRegression
# Model Number: 100 of 100 with model WindowRegression for Validation 2
# Epoch 1/100
# Template Eval Error: ValueError('Unexpected result of `train_function` (Empty logs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.') in model 100: WindowRegression
#             followers_gained
# 2021-08-31        577.476189
# 2021-09-30        613.936507
# 2021-10-31        650.412696
# 2021-11-30        686.873015
# C:\Users\saira\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "

# %% [markdown]
#             followers_gained
#
# 2021-08-31         577.476189
#
# 2021-09-30         613.936507
#
# 2021-10-31         650.412696
#
# 2021-11-30         686.873015
